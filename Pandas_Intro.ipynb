# %% [markdown]
# <a href="https://colab.research.google.com/github/jeetcodes499/club-assignments/blob/master/Pandas_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is Pandas?
# Pandas stands for **“Python Data Analysis Library"**
#
# ---
# 1. It is a Python package for data science.
# 2. It offers powerful, expressive and flexible data structures that make data manipulation and analysis easy

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-31e76ac7-52c9-48c9-b8b3-9ba7ca3dcc04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31e76ac7-52c9-48c9-b8b3-9ba7ca3dcc04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mobile-cleaned.csv to mobile-cleaned (1).csv
# ...

# %%
# !ls
# Out:
#  dataset-for-assignment.csv   sample_data	   'train (1).csv'
#  mobile-cleaned.csv	      titanic-dataset.csv   train.csv

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series
# You can think of a Series as a “column” of data, such as a collection of observations on a single variable.

# %%
s = pd.Series(np.random.randn(4))          # create the panda data type series
s
# Out:
# 0    0.884641
# 1   -1.501057
# 2    1.889777
# 3   -2.281662
# dtype: float64

# %%
s.describe()           # Generate descriptive statistics
# Out:
# count    4.000000
# mean    -0.252075
# std      1.962892
# min     -2.281662
# 25%     -1.696208
# 50%     -0.308208
# 75%      1.135925
# max      1.889777
# dtype: float64

# %% [markdown]
# # DataFrames
# While a Series is a single column of data, a DataFrame is several columns, one for each variable.
#
# It is a powerful tool for representing and analyzing data that are naturally organized  into rows and columns, often with  descriptive indexes for individual rows and individual columns.

# %%
df = pd.read_csv('mobile-cleaned.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()         # Provides a look over the first 5 entries in our data
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
df.tail()         # Provides a look over the last 5 entries in our data
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# 108         2         8         3  ...              3000               2         0
#
# [5 rows x 40 columns]

# %%
dir(df)          # return an alphabetized list of names comprising (some of) the attributes of the given object
# Out:
# ['FM',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
len(df)
# Out:
# 109

# %%
df.shape
# Out:
# (109, 40)

# %% [markdown]
# # iloc vs loc in Pandas

# %% [markdown]
# To select both rows and columns using integers, the iloc attribute can be used

# %%
df.iloc[2:5, 0:4]
# Out:
#    sim_type  aperture  gpu_rank  weight
# 2         0         9        55   142.0
# 3         0         8        55   152.0
# 4         1         1        55   234.0

# %% [markdown]
# To select rows and columns using a mixture of integers and labels, the loc attribute can be used

# %%
df.loc[4:7]
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 4         1         1        55  ...              3000             165         0
# 5         0        14        55  ...              2900             165         0
# 6         1         1        56  ...              1700             163         1
# 7         0         8        41  ...              2000              92         1
#
# [4 rows x 40 columns]

# %%
df.loc[4:7, ['gpu_rank', 'processor_frequency']]
# Out:
#    gpu_rank  processor_frequency
# 4        55                  1.3
# 5        55                  1.3
# 6        56                  1.3
# 7        41                  1.0

# %% [markdown]
# # More in Pandas

# %% [markdown]
# Selecting particular rows using standard Python array slicing notation and creating a new dataframe object from it

# %%
df.isnull()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0       False     False     False  ...             False           False     False
# 1       False     False     False  ...             False           False     False
# 2       False     False     False  ...             False           False     False
# 3       False     False     False  ...             False           False     False
# 4       False     False     False  ...             False           False     False
# ..        ...       ...       ...  ...               ...             ...       ...
# 104     False     False     False  ...             False           False     False
# 105     False     False     False  ...             False           False     False
# 106     False     False     False  ...             False           False     False
# 107     False     False     False  ...             False           False     False
# ...

# %%
df.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
df_short = df[25:30]

# %%
df_short.shape
# Out:
# (5, 40)

# %%
df_short.head()
# Out:
#     sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 25         0         8        43  ...              5000              94         1
# 26         0         8        43  ...              3000              94         1
# 27         0         8        38  ...              3000              19         1
# 28         0         1        44  ...              2100              79         1
# 29         0        10        43  ...              3100              94         1
#
# [5 rows x 40 columns]

# %%
df_short = df_short.set_index('thickness')     # Change the index
df_short
# Out:
#            sim_type  aperture  ...  processor_rank  is_liked
# thickness                      ...
# 10.6              0         8  ...              94         1
# 10.8              0         8  ...              94         1
# 9.3               0         8  ...              19         1
# 9.6               0         1  ...              79         1
# 9.4               0        10  ...              94         1
#
# [5 rows x 39 columns]

# %%
df_thin = df[['stand_by_time', 'expandable_memory', 'price', 'battery_capacity', 'is_liked']]

# %%
df_thin.shape
# Out:
# (109, 5)

# %%
df_thin.head()
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
df_liked = df_thin[df_thin['is_liked'] == 1]

# %%
df_liked.shape
# Out:
# (92, 5)

# %%
df_thin.describe()
# Out:
#        stand_by_time  expandable_memory  ...  battery_capacity    is_liked
# count      109.00000         109.000000  ...        109.000000  109.000000
# mean       404.66055         104.513761  ...       2841.779817    0.844037
# std        176.44206         275.799767  ...        655.003963    0.364496
# min        160.00000           0.000000  ...       1560.000000    0.000000
# 25%        264.00000           0.000000  ...       2470.000000    1.000000
# 50%        360.00000          32.000000  ...       2900.000000    1.000000
# 75%        500.00000         128.000000  ...       3100.000000    1.000000
# max       1093.00000        2048.000000  ...       5000.000000    1.000000
#
# [8 rows x 5 columns]

# %%
df_thin['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df_thin[df_thin['is_liked'] == 1]['price'].mean()
# Out:
# 19393.239130434784

# %%
df_thin[df_thin['is_liked'] == 0]['price'].mean()
# Out:
# 19264.823529411766

# %%
g = df_thin.groupby(['is_liked'])

# %%
for key, df_key in g:
  print(key)
  print(df_key)

# %%
df_thin.groupby(['is_liked']).describe()
# Out:
#          stand_by_time                          ... battery_capacity
#                  count        mean         std  ...              50%     75%     max
# is_liked                                        ...
# 0                 17.0  457.235294  157.094927  ...           2900.0  3000.0  4100.0
# 1                 92.0  394.945652  178.876246  ...           2900.0  3100.0  5000.0
#
# [2 rows x 32 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['price'],df['gpu_rank'], "bo")
plt.show()

# %% [markdown]
# ## Final words
# Thanks to all the bloggers and developers from where I compiled all the resources.
# Some useful refrences but not limited to:
# 1. [Pandas - Python Programming for Economics](https://python-programming.quantecon.org/pandas.html)
# 2. [What is Pandas? Why and How to Use Pandas in Python](https://www.youtube.com/watch?v=dcqPhpY7tWk)

# %% [markdown]
# Questions you should try out(dataset will be provided to you):
# 1.  Display the dataset (5 rows only)
# 2.  Display column `ParentId`
# 3.  Access 3rd row's 1st column
# 4. Display rows with  index number 7 to index number 18
# 5. Display rows where column'SomeBool' = `true`

# %%
data = pd.read_csv("dataset-for-assignment.csv")

# %%
data.head()
# Out:
#    Id  ParentId  ... SomeCountry MixedStringNumber
# 0   1      62.0  ...          AL                21
# 1   2       NaN  ...          AL               NaN
# 2   3      45.0  ...          AL                21
# 3   4      38.0  ...          AL               NaN
# 4   5       NaN  ...          AL      0.4080873354
#
# [5 rows x 14 columns]

# %%
data['ParentId']
# Out:
# 0      62.0
# 1       NaN
# 2      45.0
# 3      38.0
# 4       NaN
#        ...
# 994    42.0
# 995    48.0
# 996     NaN
# 997     NaN
# 998     NaN
# Name: ParentId, Length: 999, dtype: float64

# %%
data.iloc[2,0]
# Out:
# 3

# %%
data[data['SomeBoolean']==True]
# Out:
#       Id  ParentId  ... SomeCountry MixedStringNumber
# 0      1      62.0  ...          AL                21
# 1      2       NaN  ...          AL               NaN
# 2      3      45.0  ...          AL                21
# 3      4      38.0  ...          AL               NaN
# 4      5       NaN  ...          AL      0.4080873354
# ..   ...       ...  ...         ...               ...
# 986  987      41.0  ...         NaN               NaN
# 987  988       NaN  ...         NaN                18
# 988  989       NaN  ...         NaN       0.584634822
# 993  994       NaN  ...         NaN                19
# 996  997       NaN  ...         NaN    0.002558429094
#
# [457 rows x 14 columns]
